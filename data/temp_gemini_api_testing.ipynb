# %%
from google import genai
genai.models.Models.list
# Out:
# <function google.genai.models.Models.list(self, *, config: Union[google.genai.types.ListModelsConfig, google.genai.types.ListModelsConfigDict, NoneType] = None) -> google.genai.pagers.Pager[google.genai.types.Model]>
